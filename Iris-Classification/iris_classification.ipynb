# %%
import pandas as pd

columns = [
    "sepal_length",
    "sepal_width",
    "petal_length",
    "petal_width",
    "species"
]

df = pd.read_csv("iris/iris.csv", header=None, names=columns)

print(df.head())
print(df.shape)
